# %% [markdown]
# <a href="https://colab.research.google.com/github/JSJeong-me/CCTV/blob/main/TL_Custom_YOLOv5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # How to Train YOLOv5 on Custom Objects
#
# This tutorial is based on the [YOLOv5 repository](https://github.com/ultralytics/yolov5) by [Ultralytics](https://www.ultralytics.com/). This notebook shows training on **your own custom objects**. Many thanks to Ultralytics for putting this repository together - we hope that in combination with clean data management tools at Roboflow, this technologoy will become easily accessible to any developer wishing to use computer vision in their projects.
#
# ### Accompanying Blog Post
#
# We recommend that you follow along in this notebook while reading the blog post on [how to train YOLOv5](https://blog.roboflow.ai/how-to-train-yolov5-on-a-custom-dataset/), concurrently.
#
# ### Steps Covered in this Tutorial
#
# In this tutorial, we will walk through the steps required to train YOLOv5 on your custom objects. We use a [public blood cell detection dataset](https://public.roboflow.ai/object-detection/bccd), which is open source and free to use. You can also use this notebook on your own data.
#
# To train our detector we take the following steps:
#
# * Install YOLOv5 dependencies
# * Download custom YOLOv5 object detection data
# * Write our YOLOv5 Training configuration
# * Run YOLOv5 training
# * Evaluate YOLOv5 performance
# * Visualize YOLOv5 training data
# * Run YOLOv5 inference on test images
# * Export saved YOLOv5 weights for future inference
#
#
#
# ### **About**
#
# [Roboflow](https://roboflow.com) enables teams to deploy custom computer vision models quickly and accurately. Convert data from to annotation format, assess dataset health, preprocess, augment, and more. It's free for your first 1000 source images.

# %% [markdown]
# #Install Dependencies
#
# _(Remember to choose GPU in Runtime if not already selected. Runtime --> Change Runtime Type --> Hardware accelerator --> GPU)_

# %%
# clone YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# !git reset --hard 886f1c03d839575afecb059accf74296fad395b6
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 5784, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 5784 (delta 2), reused 2 (delta 0), pack-reused 5770
# Receiving objects: 100% (5784/5784), 8.30 MiB | 35.54 MiB/s, done.
# Resolving deltas: 100% (3945/3945), done.
# /content/yolov5
# HEAD is now at 886f1c0 DDP after autoanchor reorder (#2421)

# %%
# install dependencies as necessary
# !pip install -qr requirements.txt  # install dependencies (ignore errors)
import torch

from IPython.display import Image, clear_output  # to display images
from utils.google_utils import gdrive_download  # to download models/datasets

# clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
#      |████████████████████████████████| 645kB 19.0MB/s
# Setup complete. Using torch 1.8.1+cu101 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15109MB, multi_processor_count=40)

# %% [markdown]
# # Download Correctly Formatted Custom Dataset
#
# We'll download our dataset from Roboflow. Use the "**YOLOv5 PyTorch**" export format. Note that the Ultralytics implementation calls for a YAML file defining where your training and test data is. The Roboflow export also writes this format for us.
#
# To get your data into Roboflow, follow the [Getting Started Guide](https://blog.roboflow.ai/getting-started-with-roboflow/).

# %%
# Export code snippet and paste here
# %cd /content
# !curl -L "https://app.roboflow.com/ds/FD731jJAa9?key=Cipy64vw13" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip

# %%
# %cd ..
# Out:
# /content

# %%
# this is the YAML file Roboflow wrote for us that we're loading into this notebook with our data
# %cat data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
#
# nc: 1
# names: ['beam1']

# %% [markdown]
# # Define Model Configuration and Architecture
#
# We will write a yaml script that defines the parameters for our model like the number of classes, anchors, and each layer.
#
# You do not need to edit these cells, but you may.

# %%
# define number of classes based on YAML
import yaml
with open("data.yaml", 'r') as stream:
    num_classes = str(yaml.safe_load(stream)['nc'])

# %%
#this is the model configuration we will use for our tutorial 
# %cat /content/yolov5/models/yolov5s.yaml
# Out:
# # parameters
# nc: 80  # number of classes
# depth_multiple: 0.33  # model depth multiple
# width_multiple: 0.50  # layer channel multiple
#
# # anchors
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Focus, [64, 3]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, C3, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 9, C3, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, C3, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 1, SPP, [1024, [5, 9, 13]]],
#    [-1, 3, C3, [1024, False]],  # 9
#   ]
#
# # YOLOv5 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, C3, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 4], 1, Concat, [1]],  # cat backbone P3
#    [-1, 3, C3, [256, False]],  # 17 (P3/8-small)
#
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, 14], 1, Concat, [1]],  # cat head P4
#    [-1, 3, C3, [512, False]],  # 20 (P4/16-medium)
#
#    [-1, 1, Conv, [512, 3, 2]],
#    [[-1, 10], 1, Concat, [1]],  # cat head P5
#    [-1, 3, C3, [1024, False]],  # 23 (P5/32-large)
#
#    [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
#   ]

# %%
#customize iPython writefile so we can write variables
from IPython.core.magic import register_line_cell_magic

@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, 'w') as f:
        f.write(cell.format(**globals()))

# %%
# %%writetemplate /content/yolov5/models/custom_yolov5s.yaml
#
# # parameters
# nc: {num_classes}  # number of classes
# depth_multiple: 0.33  # model depth multiple
# width_multiple: 0.50  # layer channel multiple
#
# # anchors
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Focus, [64, 3]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, BottleneckCSP, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 9, BottleneckCSP, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, BottleneckCSP, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 1, SPP, [1024, [5, 9, 13]]],
#    [-1, 3, BottleneckCSP, [1024, False]],  # 9
#   ]
#
# # YOLOv5 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, BottleneckCSP, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 4], 1, Concat, [1]],  # cat backbone P3
#    [-1, 3, BottleneckCSP, [256, False]],  # 17 (P3/8-small)
#
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, 14], 1, Concat, [1]],  # cat head P4
#    [-1, 3, BottleneckCSP, [512, False]],  # 20 (P4/16-medium)
#
#    [-1, 1, Conv, [512, 3, 2]],
#    [[-1, 10], 1, Concat, [1]],  # cat head P5
#    [-1, 3, BottleneckCSP, [1024, False]],  # 23 (P5/32-large)
#
#    [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
#   ]

# %% [markdown]
# # Train Custom YOLOv5 Detector
#
# ### Next, we'll fire off training!
#
#
# Here, we are able to pass a number of arguments:
# - **img:** define input image size
# - **batch:** determine batch size
# - **epochs:** define the number of training epochs. (Note: often, 3000+ are common here!)
# - **data:** set the path to our yaml file
# - **cfg:** specify our model configuration
# - **weights:** specify a custom path to weights. (Note: you can download weights from the Ultralytics Google Drive [folder](https://drive.google.com/open?id=1Drs_Aiu7xx6S-ix95f9kNsA6ueKRpN2J))
# - **name:** result names
# - **nosave:** only save the final checkpoint
# - **cache:** cache images for faster training

# %%
# train yolov5s on custom data for 100 epochs
# time its performance
# %%time
# %cd /content/yolov5/
# !python train.py --batch 8 --weights yolov5s.pt --data '../data.yaml' --epochs 500 --cache --img 416 --hyp hyp.finetune.yaml --name yolov5s_results
# Out:
# /content/yolov5
# github: ⚠️ WARNING: code is out of date by 84 commits. Use 'git pull' to update or 'git clone https://github.com/ultralytics/yolov5' to download latest.
# YOLOv5 v4.0-126-g886f1c0 torch 1.8.1+cu101 CUDA:0 (Tesla T4, 15109.75MB)
#
# Namespace(adam=False, batch_size=8, bucket='', cache_images=True, cfg='', data='../data.yaml', device='', entity=None, epochs=500, evolve=False, exist_ok=False, global_rank=-1, hyp='./data/hyp.finetune.yaml', image_weights=False, img_size=[416, 416], linear_lr=False, local_rank=-1, log_artifacts=False, log_imgs=16, multi_scale=False, name='yolov5s_results', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/yolov5s_results3', single_cls=False, sync_bn=False, total_batch_size=8, weights='yolov5s.pt', workers=8, world_size=1)
# wandb: Install Weights & Biases for YOLOv5 logging with 'pip install wandb' (recommended)
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# 2021-04-20 03:46:48.429025: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# hyperparameters: lr0=0.0032, lrf=0.12, momentum=0.843, weight_decay=0.00036, warmup_epochs=2.0, warmup_momentum=0.5, warmup_bias_lr=0.05, box=0.0296, cls=0.243, cls_pw=0.631, obj=0.301, obj_pw=0.911, iou_t=0.2, anchor_t=2.91, fl_gamma=0.0, hsv_h=0.0138, hsv_s=0.664, hsv_v=0.464, degrees=0.373, translate=0.245, scale=0.898, shear=0.602, perspective=0.0, flipud=0.00856, fliplr=0.5, mosaic=1.0, mixup=0.243
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Focus                     [3, 32, 3]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1    156928  models.common.C3                        [128, 128, 3]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  1    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1    656896  models.common.SPP                       [512, 512, [5, 9, 13]]
#   9                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model Summary: 283 layers, 7063542 parameters, 7063542 gradients, 16.4 GFLOPS
#
# Transferred 356/362 items from yolov5s.pt
# freezing model.0.conv.conv.weight
# freezing model.0.conv.bn.weight
# freezing model.0.conv.bn.bias
# freezing model.1.conv.weight
# freezing model.1.bn.weight
# freezing model.1.bn.bias
# freezing model.2.cv1.conv.weight
# freezing model.2.cv1.bn.weight
# freezing model.2.cv1.bn.bias
# freezing model.2.cv2.conv.weight
# freezing model.2.cv2.bn.weight
# freezing model.2.cv2.bn.bias
# freezing model.2.cv3.conv.weight
# freezing model.2.cv3.bn.weight
# freezing model.2.cv3.bn.bias
# freezing model.2.m.0.cv1.conv.weight
# freezing model.2.m.0.cv1.bn.weight
# freezing model.2.m.0.cv1.bn.bias
# freezing model.2.m.0.cv2.conv.weight
# freezing model.2.m.0.cv2.bn.weight
# freezing model.2.m.0.cv2.bn.bias
# freezing model.3.conv.weight
# freezing model.3.bn.weight
# freezing model.3.bn.bias
# freezing model.4.cv1.conv.weight
# freezing model.4.cv1.bn.weight
# freezing model.4.cv1.bn.bias
# freezing model.4.cv2.conv.weight
# freezing model.4.cv2.bn.weight
# freezing model.4.cv2.bn.bias
# freezing model.4.cv3.conv.weight
# freezing model.4.cv3.bn.weight
# freezing model.4.cv3.bn.bias
# freezing model.4.m.0.cv1.conv.weight
# freezing model.4.m.0.cv1.bn.weight
# freezing model.4.m.0.cv1.bn.bias
# freezing model.4.m.0.cv2.conv.weight
# freezing model.4.m.0.cv2.bn.weight
# freezing model.4.m.0.cv2.bn.bias
# freezing model.4.m.1.cv1.conv.weight
# freezing model.4.m.1.cv1.bn.weight
# freezing model.4.m.1.cv1.bn.bias
# freezing model.4.m.1.cv2.conv.weight
# freezing model.4.m.1.cv2.bn.weight
# freezing model.4.m.1.cv2.bn.bias
# freezing model.4.m.2.cv1.conv.weight
# freezing model.4.m.2.cv1.bn.weight
# freezing model.4.m.2.cv1.bn.bias
# freezing model.4.m.2.cv2.conv.weight
# freezing model.4.m.2.cv2.bn.weight
# freezing model.4.m.2.cv2.bn.bias
# freezing model.5.conv.weight
# freezing model.5.bn.weight
# freezing model.5.bn.bias
# freezing model.6.cv1.conv.weight
# freezing model.6.cv1.bn.weight
# freezing model.6.cv1.bn.bias
# freezing model.6.cv2.conv.weight
# freezing model.6.cv2.bn.weight
# freezing model.6.cv2.bn.bias
# freezing model.6.cv3.conv.weight
# freezing model.6.cv3.bn.weight
# freezing model.6.cv3.bn.bias
# freezing model.6.m.0.cv1.conv.weight
# freezing model.6.m.0.cv1.bn.weight
# freezing model.6.m.0.cv1.bn.bias
# freezing model.6.m.0.cv2.conv.weight
# freezing model.6.m.0.cv2.bn.weight
# freezing model.6.m.0.cv2.bn.bias
# freezing model.6.m.1.cv1.conv.weight
# freezing model.6.m.1.cv1.bn.weight
# freezing model.6.m.1.cv1.bn.bias
# freezing model.6.m.1.cv2.conv.weight
# freezing model.6.m.1.cv2.bn.weight
# freezing model.6.m.1.cv2.bn.bias
# freezing model.6.m.2.cv1.conv.weight
# freezing model.6.m.2.cv1.bn.weight
# freezing model.6.m.2.cv1.bn.bias
# freezing model.6.m.2.cv2.conv.weight
# freezing model.6.m.2.cv2.bn.weight
# freezing model.6.m.2.cv2.bn.bias
# freezing model.7.conv.weight
# freezing model.7.bn.weight
# freezing model.7.bn.bias
# freezing model.8.cv1.conv.weight
# freezing model.8.cv1.bn.weight
# freezing model.8.cv1.bn.bias
# freezing model.8.cv2.conv.weight
# freezing model.8.cv2.bn.weight
# freezing model.8.cv2.bn.bias
# freezing model.9.cv1.conv.weight
# freezing model.9.cv1.bn.weight
# freezing model.9.cv1.bn.bias
# freezing model.9.cv2.conv.weight
# freezing model.9.cv2.bn.weight
# freezing model.9.cv2.bn.bias
# freezing model.9.cv3.conv.weight
# freezing model.9.cv3.bn.weight
# freezing model.9.cv3.bn.bias
# freezing model.9.m.0.cv1.conv.weight
# freezing model.9.m.0.cv1.bn.weight
# freezing model.9.m.0.cv1.bn.bias
# freezing model.9.m.0.cv2.conv.weight
# freezing model.9.m.0.cv2.bn.weight
# freezing model.9.m.0.cv2.bn.bias
# Scaled weight_decay = 0.00036
# Optimizer groups: 62 .bias, 62 conv.weight, 59 other
# train: Scanning '../train/labels.cache' for images and labels... 51 found, 0 missing, 0 empty, 0 corrupted: 100% 51/51 [00:00<00:00, 540175.52it/s]
# train: Caching images (0.0GB): 100% 51/51 [00:00<00:00, 295.74it/s]
# val: Scanning '../valid/labels.cache' for images and labels... 3 found, 0 missing, 0 empty, 0 corrupted: 100% 3/3 [00:00<00:00, 2359.44it/s]
# val: Caching images (0.0GB): 100% 3/3 [00:00<00:00, 141.62it/s]
# Plotting labels...
#
# autoanchor: Analyzing anchors... anchors/target = 3.96, Best Possible Recall (BPR) = 1.0000
# Image sizes 416 train, 416 test
# Using 2 dataloader workers
# Logging results to runs/train/yolov5s_results3
# Starting training for 500 epochs...
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      0/499     1.35G   0.06516   0.00596         0   0.07112        12       416: 100% 7/7 [00:01<00:00,  4.87it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.83it/s]
#                  all           3           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      1/499     1.38G   0.06596  0.005494         0   0.07146         7       416: 100% 7/7 [00:00<00:00, 12.93it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 27.45it/s]
#                  all           3           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      2/499     1.38G   0.06728   0.00549         0   0.07277        14       416: 100% 7/7 [00:00<00:00, 12.49it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 29.68it/s]
#                  all           3           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      3/499     1.38G   0.06624  0.005397         0   0.07164        12       416: 100% 7/7 [00:00<00:00, 12.04it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 24.38it/s]
#                  all           3           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      4/499     1.38G   0.06451  0.006482         0   0.07099        15       416: 100% 7/7 [00:00<00:00, 12.27it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 27.35it/s]
#                  all           3           6     0.00165       0.167    0.000302    3.02e-05
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      5/499     1.38G   0.06665  0.005472         0   0.07212         8       416: 100% 7/7 [00:00<00:00, 11.13it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 28.15it/s]
#                  all           3           6     0.00327       0.333     0.00122    0.000122
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      6/499     1.38G   0.06357  0.006122         0   0.06969         8       416: 100% 7/7 [00:00<00:00, 12.27it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 25.66it/s]
#                  all           3           6      0.0163       0.167     0.00479    0.000515
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      7/499     1.38G   0.06812  0.004992         0   0.07311        10       416: 100% 7/7 [00:00<00:00, 11.38it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 23.50it/s]
#                  all           3           6      0.0141       0.167     0.00466    0.000501
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      8/499     1.38G   0.06377  0.005327         0    0.0691         7       416: 100% 7/7 [00:00<00:00, 11.50it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 23.94it/s]
#                  all           3           6      0.0141       0.167     0.00429    0.000731
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      9/499     1.38G   0.06358  0.005776         0   0.06935        11       416: 100% 7/7 [00:00<00:00, 12.23it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 27.99it/s]
#                  all           3           6      0.0113       0.167     0.00275    0.000275
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     10/499     1.38G   0.06459  0.005694         0   0.07028        12       416: 100% 7/7 [00:00<00:00, 11.69it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 25.75it/s]
#                  all           3           6     0.00997       0.167      0.0047    0.000535
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     11/499     1.38G   0.06457  0.005721         0   0.07029         7       416: 100% 7/7 [00:00<00:00, 13.93it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 23.97it/s]
#                  all           3           6      0.0104       0.167      0.0049    0.000591
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     12/499     1.38G   0.06546  0.005952         0   0.07141        12       416: 100% 7/7 [00:00<00:00, 12.80it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 28.07it/s]
#                  all           3           6     0.00703         0.5     0.00387    0.000954
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     13/499     1.38G   0.06253  0.006246         0   0.06878        12       416: 100% 7/7 [00:00<00:00, 13.46it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 22.84it/s]
#                  all           3           6     0.00673       0.333     0.00354    0.000629
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     14/499     1.38G    0.0621  0.004771         0   0.06687         4       416: 100% 7/7 [00:00<00:00, 12.30it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 27.06it/s]
#                  all           3           6     0.00677       0.333     0.00364    0.000717
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     15/499     1.38G   0.06182  0.006071         0   0.06789        14       416: 100% 7/7 [00:00<00:00, 13.64it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 22.11it/s]
#                  all           3           6     0.00831         0.5     0.00418    0.000664
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     16/499     1.38G   0.06596  0.005821         0   0.07178        17       416: 100% 7/7 [00:00<00:00, 12.68it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 30.09it/s]
#                  all           3           6     0.00792         0.5     0.00434    0.000483
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     17/499     1.38G   0.06218  0.005611         0   0.06779        12       416: 100% 7/7 [00:00<00:00, 14.68it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 20.45it/s]
#                  all           3           6     0.00416       0.333     0.00155      0.0002
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     18/499     1.38G   0.06417  0.005687         0   0.06986        10       416: 100% 7/7 [00:00<00:00, 13.91it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 27.61it/s]
#                  all           3           6      0.0212       0.167     0.00479    0.000479
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     19/499     1.38G   0.06307  0.005705         0   0.06878         6       416: 100% 7/7 [00:00<00:00, 14.56it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 20.47it/s]
#                  all           3           6      0.0191       0.167     0.00428    0.000428
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     20/499     1.38G   0.06093   0.00533         0   0.06626         3       416: 100% 7/7 [00:00<00:00, 12.19it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 27.66it/s]
#                  all           3           6      0.0174       0.167     0.00656    0.000714
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     21/499     1.38G   0.06105  0.006246         0   0.06729         7       416: 100% 7/7 [00:00<00:00, 13.55it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 26.94it/s]
#                  all           3           6       0.018       0.167     0.00657     0.00111
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     22/499     1.38G   0.06374  0.006127         0   0.06987        13       416: 100% 7/7 [00:00<00:00, 12.52it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 30.01it/s]
#                  all           3           6      0.0181       0.167      0.0069     0.00138
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     23/499     1.38G   0.06306  0.005568         0   0.06863         7       416: 100% 7/7 [00:00<00:00, 14.03it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 20.43it/s]
#                  all           3           6      0.0206       0.167     0.00683     0.00151
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     24/499     1.38G   0.06107  0.006786         0   0.06785        15       416: 100% 7/7 [00:00<00:00, 13.14it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 30.23it/s]
#                  all           3           6      0.0301       0.333      0.0147      0.0022
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     25/499     1.38G   0.05783  0.006415         0   0.06425         2       416: 100% 7/7 [00:00<00:00, 14.62it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 20.59it/s]
#                  all           3           6      0.0203       0.333      0.0107      0.0021
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     26/499     1.38G   0.06272  0.006001         0   0.06872        14       416: 100% 7/7 [00:00<00:00, 12.39it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 23.71it/s]
#                  all           3           6       0.016       0.167     0.00588     0.00163
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     27/499     1.38G   0.06243  0.006588         0   0.06901        10       416: 100% 7/7 [00:00<00:00, 13.31it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 30.16it/s]
#                  all           3           6      0.0133       0.167     0.00331     0.00115
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     28/499     1.38G   0.06171  0.006549         0   0.06826        11       416: 100% 7/7 [00:00<00:00, 13.18it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 24.91it/s]
#                  all           3           6      0.0128       0.167     0.00308     0.00106
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     29/499     1.38G   0.05788  0.006289         0   0.06417        15       416: 100% 7/7 [00:00<00:00, 13.82it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 22.33it/s]
#                  all           3           6      0.0131       0.167      0.0031    0.000757
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     30/499     1.38G   0.05796   0.00623         0   0.06419         6       416: 100% 7/7 [00:00<00:00, 13.22it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 30.82it/s]
#                  all           3           6      0.0129       0.167     0.00215     0.00043
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     31/499     1.38G   0.05943  0.005979         0   0.06541         5       416: 100% 7/7 [00:00<00:00, 13.80it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 26.07it/s]
#                  all           3           6      0.0137       0.167     0.00236    0.000709
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     32/499     1.38G   0.05937  0.005947         0   0.06531        10       416: 100% 7/7 [00:00<00:00, 13.92it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 23.30it/s]
#                  all           3           6      0.0132       0.167     0.00276    0.000551
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     33/499     1.38G   0.05929  0.006091         0   0.06538        11       416: 100% 7/7 [00:00<00:00, 13.75it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 30.56it/s]
#                  all           3           6      0.0139       0.167      0.0024     0.00048
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     34/499     1.38G    0.0587  0.006762         0   0.06546        11       416: 100% 7/7 [00:00<00:00, 14.84it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 22.40it/s]
#                  all           3           6      0.0138       0.167     0.00236    0.000473
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     35/499     1.38G    0.0569  0.005943         0   0.06284        14       416: 100% 7/7 [00:00<00:00, 14.54it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 19.80it/s]
#                  all           3           6      0.0127       0.167     0.00236    0.000473
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     36/499     1.38G   0.05915  0.007213         0   0.06636        11       416: 100% 7/7 [00:00<00:00, 13.14it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 26.66it/s]
#                  all           3           6      0.0103       0.167     0.00193    0.000385
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     37/499     1.38G   0.05889  0.006882         0   0.06577         8       416: 100% 7/7 [00:00<00:00, 13.96it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 28.51it/s]
#                  all           3           6      0.0102       0.167     0.00195    0.000195
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     38/499     1.38G   0.05899  0.006067         0   0.06506         9       416: 100% 7/7 [00:00<00:00, 13.85it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 22.65it/s]
#                  all           3           6      0.0106       0.167     0.00207    0.000207
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     39/499     1.38G   0.05986  0.006528         0   0.06639        13       416: 100% 7/7 [00:00<00:00, 13.62it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 30.63it/s]
#                  all           3           6      0.0107       0.167     0.00207    0.000414
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     40/499     1.38G    0.0586  0.006448         0   0.06505        16       416: 100% 7/7 [00:00<00:00, 14.74it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 24.25it/s]
#                  all           3           6      0.0111       0.167      0.0021    0.000419
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     41/499     1.38G   0.05873  0.006369         0    0.0651        13       416: 100% 7/7 [00:00<00:00, 12.76it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 26.32it/s]
#                  all           3           6      0.0113       0.167     0.00218    0.000436
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     42/499     1.38G   0.05977  0.006615         0   0.06638        11       416: 100% 7/7 [00:00<00:00, 12.61it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 25.17it/s]
#                  all           3           6      0.0119       0.167     0.00218    0.000654
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     43/499     1.38G    0.0603  0.006777         0   0.06708        18       416: 100% 7/7 [00:00<00:00, 14.64it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 25.99it/s]
#                  all           3           6      0.0121       0.167     0.00221    0.000662
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     44/499     1.38G   0.05543  0.005885         0   0.06132         3       416: 100% 7/7 [00:00<00:00, 15.68it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 20.21it/s]
#                  all           3           6      0.0102       0.167     0.00202    0.000606
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     45/499     1.38G    0.0579  0.006618         0   0.06452        12       416: 100% 7/7 [00:00<00:00, 14.05it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 31.07it/s]
#                  all           3           6      0.0105       0.167     0.00178    0.000356
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     46/499     1.38G   0.05642  0.007085         0   0.06351        17       416: 100% 7/7 [00:00<00:00, 12.74it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 28.10it/s]
#                  all           3           6      0.0111       0.167     0.00184    0.000368
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     47/499     1.38G   0.05867  0.006649         0   0.06532        21       416: 100% 7/7 [00:00<00:00, 14.74it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 24.27it/s]
#                  all           3           6      0.0119       0.167     0.00204    0.000409
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     48/499     1.38G   0.05847  0.007059         0   0.06553        13       416: 100% 7/7 [00:00<00:00, 13.57it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 31.14it/s]
#                  all           3           6      0.0111       0.167      0.0019    0.000381
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     49/499     1.38G    0.0573  0.006253         0   0.06355         8       416: 100% 7/7 [00:00<00:00, 14.64it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 26.11it/s]
#                  all           3           6      0.0112       0.167     0.00215    0.000215
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     50/499     1.38G   0.05762  0.006513         0   0.06413         9       416: 100% 7/7 [00:00<00:00, 15.18it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 24.44it/s]
#                  all           3           6      0.0134       0.167     0.00224    0.000224
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     51/499     1.38G   0.05418  0.006827         0   0.06101         6       416: 100% 7/7 [00:00<00:00, 13.36it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 23.64it/s]
#                  all           3           6     0.00719       0.167     0.00122    0.000366
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     52/499     1.38G   0.05689  0.006121         0   0.06301         7       416: 100% 7/7 [00:00<00:00, 14.43it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 21.36it/s]
#                  all           3           6     0.00707       0.167     0.00142    0.000425
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     53/499     1.38G   0.05757  0.006881         0   0.06445        15       416: 100% 7/7 [00:00<00:00, 15.24it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 28.14it/s]
#                  all           3           6     0.00717       0.167     0.00135    0.000405
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     54/499     1.38G   0.05991  0.005843         0   0.06575        13       416: 100% 7/7 [00:00<00:00, 14.44it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 28.47it/s]
#                  all           3           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     55/499     1.38G   0.05597  0.007577         0   0.06354        17       416: 100% 7/7 [00:00<00:00, 15.46it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 21.32it/s]
#                  all           3           6     0.00719       0.167     0.00119    0.000119
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     56/499     1.38G   0.05224  0.006306         0   0.05855         4       416: 100% 7/7 [00:00<00:00, 14.91it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 20.62it/s]
#                  all           3           6     0.00668       0.167     0.00113    0.000113
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     57/499     1.38G    0.0561  0.006937         0   0.06303        16       416: 100% 7/7 [00:00<00:00, 14.72it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 29.23it/s]
#                  all           3           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     58/499     1.38G   0.05698  0.005771         0   0.06275         7       416: 100% 7/7 [00:00<00:00, 14.46it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 27.53it/s]
#                  all           3           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     59/499     1.38G   0.05456   0.00672         0   0.06128        10       416: 100% 7/7 [00:00<00:00, 15.70it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 20.70it/s]
#                  all           3           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     60/499     1.38G   0.05624  0.006042         0   0.06228         5       416: 100% 7/7 [00:00<00:00, 14.73it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 20.85it/s]
#                  all           3           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     61/499     1.38G   0.05285  0.006545         0    0.0594         4       416: 100% 7/7 [00:00<00:00, 13.42it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 21.59it/s]
#                  all           3           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     62/499     1.38G   0.05363   0.00621         0   0.05984         6       416: 100% 7/7 [00:00<00:00, 15.25it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 21.91it/s]
#                  all           3           6      0.0115       0.167     0.00197    0.000197
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     63/499     1.38G   0.05497  0.006866         0   0.06183         9       416: 100% 7/7 [00:00<00:00, 14.72it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 29.87it/s]
#                  all           3           6      0.0116       0.167     0.00193    0.000193
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     64/499     1.38G   0.05685  0.006165         0   0.06302         8       416: 100% 7/7 [00:00<00:00, 14.61it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 23.83it/s]
#                  all           3           6      0.0114       0.167     0.00197    0.000197
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     65/499     1.38G   0.05523   0.00638         0   0.06161         7       416: 100% 7/7 [00:00<00:00, 15.15it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 26.19it/s]
#                  all           3           6     0.00985       0.167     0.00184    0.000184
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     66/499     1.38G   0.05518   0.00703         0   0.06221         7       416: 100% 7/7 [00:00<00:00, 13.41it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 31.71it/s]
#                  all           3           6      0.0101       0.167     0.00176    0.000176
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     67/499     1.38G   0.05682  0.006048         0   0.06286        11       416: 100% 7/7 [00:00<00:00, 13.82it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 28.20it/s]
#                  all           3           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     68/499     1.38G   0.05309  0.007647         0   0.06074        12       416: 100% 7/7 [00:00<00:00, 14.13it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 27.44it/s]
#                  all           3           6      0.0101       0.167     0.00176    0.000176
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     69/499     1.38G   0.05316  0.006825         0   0.05999         7       416: 100% 7/7 [00:00<00:00, 14.31it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 17.75it/s]
#                  all           3           6      0.0107       0.167     0.00182    0.000182
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     70/499     1.38G   0.05383    0.0061         0   0.05993         6       416: 100% 7/7 [00:00<00:00, 14.13it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 28.57it/s]
#                  all           3           6      0.0106       0.167     0.00188    0.000188
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     71/499     1.38G   0.05155  0.006874         0   0.05842         4       416: 100% 7/7 [00:00<00:00, 13.93it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 21.22it/s]
#                  all           3           6      0.0111       0.167       0.002      0.0002
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     72/499     1.38G   0.05418  0.006697         0   0.06088        15       416: 100% 7/7 [00:00<00:00, 14.42it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 20.48it/s]
#                  all           3           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     73/499     1.38G   0.05339  0.007446         0   0.06083        13       416: 100% 7/7 [00:00<00:00, 13.88it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 26.26it/s]
#                  all           3           6     0.00431       0.167    0.000764    7.64e-05
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     74/499     1.38G   0.05348  0.007444         0   0.06092         7       416: 100% 7/7 [00:00<00:00, 15.15it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 19.23it/s]
#                  all           3           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     75/499     1.38G   0.05177  0.006331         0    0.0581         8       416: 100% 7/7 [00:00<00:00, 13.93it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 26.38it/s]
#                  all           3           6      0.0049       0.167    0.000934    9.34e-05
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     76/499     1.38G   0.05275  0.006805         0   0.05956        15       416: 100% 7/7 [00:00<00:00, 14.11it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 22.30it/s]
#                  all           3           6     0.00376       0.167    0.000701    7.01e-05
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     77/499     1.38G   0.05312  0.006674         0   0.05979         6       416: 100% 7/7 [00:00<00:00, 13.91it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 27.67it/s]
#                  all           3           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     78/499     1.38G   0.05264  0.006646         0   0.05929        12       416: 100% 7/7 [00:00<00:00, 14.50it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 29.20it/s]
#                  all           3           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     79/499     1.38G   0.04983  0.006045         0   0.05587         3       416: 100% 7/7 [00:00<00:00, 15.82it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 23.76it/s]
#                  all           3           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     80/499     1.38G   0.05209  0.006917         0   0.05901        17       416: 100% 7/7 [00:00<00:00, 14.09it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 20.56it/s]
#                  all           3           6     0.00618       0.167     0.00107    0.000107
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     81/499     1.38G   0.05289  0.007138         0   0.06003        14       416: 100% 7/7 [00:00<00:00, 14.50it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 25.19it/s]
#                  all           3           6     0.00536       0.167       0.001      0.0001
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     82/499     1.38G   0.05238  0.008228         0    0.0606        20       416: 100% 7/7 [00:00<00:00, 14.07it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 31.81it/s]
#                  all           3           6      0.0054       0.167    0.000972    9.72e-05
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     83/499     1.38G   0.05342  0.006549         0   0.05997        14       416: 100% 7/7 [00:00<00:00, 14.53it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 26.97it/s]
#                  all           3           6     0.00548       0.167     0.00099     9.9e-05
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     84/499     1.38G   0.05227  0.006042         0   0.05832        10       416: 100% 7/7 [00:00<00:00, 14.92it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 25.24it/s]
#                  all           3           6     0.00564       0.167    0.000956    9.56e-05
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     85/499     1.38G   0.05111  0.007021         0   0.05813         9       416: 100% 7/7 [00:00<00:00, 14.68it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 25.67it/s]
#                  all           3           6     0.00566       0.167     0.00109    0.000109
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     86/499     1.38G    0.0511  0.006231         0   0.05733         6       416: 100% 7/7 [00:00<00:00, 14.94it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 21.75it/s]
#                  all           3           6     0.00573       0.167     0.00108    0.000108
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     87/499     1.38G   0.05007  0.006879         0   0.05695         5       416: 100% 7/7 [00:00<00:00, 14.54it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 29.90it/s]
#                  all           3           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     88/499     1.38G   0.05256  0.006658         0   0.05921        14       416: 100% 7/7 [00:00<00:00, 15.09it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 23.16it/s]
#                  all           3           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     89/499     1.38G      0.05  0.007432         0   0.05743        13       416: 100% 7/7 [00:00<00:00, 14.67it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 24.42it/s]
#                  all           3           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     90/499     1.38G   0.05011  0.006175         0   0.05629         5       416: 100% 7/7 [00:00<00:00, 14.53it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 19.93it/s]
#                  all           3           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     91/499     1.38G   0.05079  0.006638         0   0.05743         5       416: 100% 7/7 [00:00<00:00, 15.43it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 25.78it/s]
#                  all           3           6     0.00284       0.167    0.000518    5.18e-05
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     92/499     1.38G    0.0495  0.007215         0   0.05672         5       416: 100% 7/7 [00:00<00:00, 14.40it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 21.05it/s]
#                  all           3           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     93/499     1.38G    0.0476  0.006903         0   0.05451         5       416: 100% 7/7 [00:00<00:00, 15.45it/s]
# ...
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 32.33it/s]
#                  all           3           6       0.998         0.5       0.597       0.193
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    463/499     1.38G   0.03257  0.006957         0   0.03952        14       416: 100% 7/7 [00:00<00:00, 14.80it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 22.97it/s]
#                  all           3           6       0.998         0.5       0.597       0.193
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    464/499     1.38G   0.03414  0.006524         0   0.04066         7       416: 100% 7/7 [00:00<00:00, 14.83it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 13.10it/s]
#                  all           3           6       0.998         0.5       0.597       0.212
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    465/499     1.38G   0.03208  0.006589         0   0.03867         4       416: 100% 7/7 [00:00<00:00, 14.37it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 27.93it/s]
#                  all           3           6       0.997         0.5       0.598       0.193
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    466/499     1.38G   0.03023  0.006315         0   0.03655         5       416: 100% 7/7 [00:00<00:00, 13.66it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 28.55it/s]
#                  all           3           6       0.998         0.5       0.597       0.212
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    467/499     1.38G   0.03311  0.006819         0   0.03993        11       416: 100% 7/7 [00:00<00:00, 13.66it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 26.83it/s]
#                  all           3           6           1         0.5       0.598       0.234
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    468/499     1.38G   0.03206  0.006524         0   0.03859        14       416: 100% 7/7 [00:00<00:00, 14.88it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 21.66it/s]
#                  all           3           6           1         0.5       0.598       0.174
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    469/499     1.38G   0.03398  0.008025         0     0.042        14       416: 100% 7/7 [00:00<00:00, 14.28it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 25.84it/s]
#                  all           3           6           1       0.499       0.598       0.174
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    470/499     1.38G   0.02866  0.006103         0   0.03476        12       416: 100% 7/7 [00:00<00:00, 15.12it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 30.82it/s]
#                  all           3           6       0.997         0.5       0.598       0.174
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    471/499     1.38G   0.03238  0.006119         0    0.0385        12       416: 100% 7/7 [00:00<00:00, 16.28it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 16.65it/s]
#                  all           3           6       0.997         0.5       0.598       0.174
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    472/499     1.38G   0.03086  0.006167         0   0.03702        12       416: 100% 7/7 [00:00<00:00, 14.81it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 32.11it/s]
#                  all           3           6           1         0.5       0.614       0.181
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    473/499     1.38G   0.02902  0.006409         0   0.03543         4       416: 100% 7/7 [00:00<00:00, 14.45it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 24.13it/s]
#                  all           3           6           1         0.5       0.614       0.181
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    474/499     1.38G   0.03222   0.00651         0   0.03873        11       416: 100% 7/7 [00:00<00:00, 14.07it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 27.39it/s]
#                  all           3           6           1         0.5       0.598       0.174
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    475/499     1.38G   0.03265  0.006793         0   0.03944        15       416: 100% 7/7 [00:00<00:00, 15.24it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 25.23it/s]
#                  all           3           6       0.997         0.5       0.598       0.193
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    476/499     1.38G   0.03307  0.006553         0   0.03963        15       416: 100% 7/7 [00:00<00:00, 13.80it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 27.24it/s]
#                  all           3           6           1         0.5       0.614         0.2
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    477/499     1.38G   0.03117  0.006398         0   0.03757         8       416: 100% 7/7 [00:00<00:00, 14.61it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 30.37it/s]
#                  all           3           6           1       0.499       0.614         0.2
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    478/499     1.38G   0.03201  0.005407         0   0.03742         6       416: 100% 7/7 [00:00<00:00, 14.75it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 28.89it/s]
#                  all           3           6           1         0.5       0.615         0.2
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    479/499     1.38G   0.02801  0.005968         0   0.03397         6       416: 100% 7/7 [00:00<00:00, 14.12it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 30.05it/s]
#                  all           3           6           1         0.5       0.615         0.2
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    480/499     1.38G   0.03276  0.007393         0   0.04015        21       416: 100% 7/7 [00:00<00:00, 14.19it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 23.75it/s]
#                  all           3           6           1         0.5       0.614       0.181
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    481/499     1.38G   0.02988  0.006428         0    0.0363        11       416: 100% 7/7 [00:00<00:00, 13.79it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 23.28it/s]
#                  all           3           6           1       0.499       0.614       0.161
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    482/499     1.38G   0.03441  0.007021         0   0.04143        14       416: 100% 7/7 [00:00<00:00, 14.31it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 29.53it/s]
#                  all           3           6           1       0.499       0.586       0.169
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    483/499     1.38G   0.03283  0.006239         0   0.03907        11       416: 100% 7/7 [00:00<00:00, 13.38it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 24.77it/s]
#                  all           3           6       0.998         0.5       0.585        0.15
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    484/499     1.38G   0.03373  0.007508         0   0.04124        15       416: 100% 7/7 [00:00<00:00, 12.44it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 27.89it/s]
#                  all           3           6           1         0.5       0.586       0.169
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    485/499     1.38G   0.03173  0.006398         0   0.03812         9       416: 100% 7/7 [00:00<00:00, 13.68it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 21.16it/s]
#                  all           3           6       0.998         0.5       0.585       0.169
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    486/499     1.38G   0.03478  0.005597         0   0.04038         6       416: 100% 7/7 [00:00<00:00, 13.78it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 28.11it/s]
#                  all           3           6       0.998         0.5       0.598       0.174
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    487/499     1.38G   0.03323  0.006993         0   0.04022        17       416: 100% 7/7 [00:00<00:00, 15.67it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 19.50it/s]
#                  all           3           6       0.998         0.5       0.598       0.174
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    488/499     1.38G   0.02989  0.006384         0   0.03628        10       416: 100% 7/7 [00:00<00:00, 14.02it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 32.97it/s]
#                  all           3           6       0.998         0.5       0.586       0.169
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    489/499     1.38G   0.03128  0.006048         0   0.03733        11       416: 100% 7/7 [00:00<00:00, 14.32it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 32.71it/s]
#                  all           3           6           1         0.5       0.586       0.169
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    490/499     1.38G   0.03226  0.006637         0    0.0389        21       416: 100% 7/7 [00:00<00:00, 14.95it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 15.77it/s]
#                  all           3           6       0.998         0.5       0.585       0.169
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    491/499     1.38G   0.03153  0.008348         0   0.03988        12       416: 100% 7/7 [00:00<00:00, 13.12it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 23.41it/s]
#                  all           3           6           1       0.499       0.576       0.184
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    492/499     1.38G    0.0291  0.006725         0   0.03582        15       416: 100% 7/7 [00:00<00:00, 14.52it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 24.22it/s]
#                  all           3           6           1       0.499       0.586       0.188
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    493/499     1.38G   0.02986  0.006561         0   0.03642         8       416: 100% 7/7 [00:00<00:00, 12.98it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 31.95it/s]
#                  all           3           6           1       0.499       0.586       0.206
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    494/499     1.38G   0.03192  0.005865         0   0.03779         7       416: 100% 7/7 [00:00<00:00, 15.55it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 26.15it/s]
#                  all           3           6       0.998         0.5       0.586       0.188
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    495/499     1.38G   0.03391  0.007077         0   0.04099        12       416: 100% 7/7 [00:00<00:00, 15.19it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 24.64it/s]
#                  all           3           6       0.998         0.5       0.586       0.188
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    496/499     1.38G   0.03248  0.007367         0   0.03985        19       416: 100% 7/7 [00:00<00:00, 13.00it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 20.26it/s]
#                  all           3           6       0.999         0.5       0.585       0.188
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    497/499     1.38G   0.02909  0.005965         0   0.03506         7       416: 100% 7/7 [00:00<00:00, 13.21it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 32.46it/s]
#                  all           3           6           1       0.499       0.597       0.174
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    498/499     1.38G   0.03092  0.006941         0   0.03786         5       416: 100% 7/7 [00:00<00:00, 13.99it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 15.77it/s]
#                  all           3           6           1         0.5       0.597       0.174
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    499/499     1.38G   0.03185  0.007182         0   0.03904         5       416: 100% 7/7 [00:00<00:00, 14.03it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.64it/s]
#                  all           3           6           1       0.499       0.597       0.172
# Optimizer stripped from runs/train/yolov5s_results3/weights/last.pt, 14.4MB
# Optimizer stripped from runs/train/yolov5s_results3/weights/best.pt, 14.4MB
# 500 epochs completed in 0.158 hours.
#
# CPU times: user 5.29 s, sys: 805 ms, total: 6.09 s
# Wall time: 9min 40s

# %%
# %%time
# %cd /content/yolov5/
# !python train.py --batch 8 --weights yolov5s.pt --data '../data.yaml' --epochs 300 --cache --img 640 --hyp hyp.finetune.yaml --name yolov5s_results

# %% [markdown]
# # Evaluate Custom YOLOv5 Detector Performance

# %% [markdown]
# Training losses and performance metrics are saved to Tensorboard and also to a logfile defined above with the **--name** flag when we train. In our case, we named this `yolov5s_results`. (If given no name, it defaults to `results.txt`.) The results file is plotted as a png after training completes.
#
# Note from Glenn: Partially completed `results.txt` files can be plotted with `from utils.utils import plot_results; plot_results()`.

# %%
# Start tensorboard
# Launch after you have started training
# logs save in the folder "runs"
# %load_ext tensorboard
# %tensorboard --logdir runs

# %%
# we can also output some older school graphs if the tensor board isn't working for whatever reason... 
from utils.plots import plot_results  # plot results.txt as results.png
Image(filename='/content/yolov5/runs/train/yolov5s_results2/results.png', width=1000)  # view results.png

# %% [markdown]
# ### Curious? Visualize Our Training Data with Labels
#
# After training starts, view `train*.jpg` images to see training images, labels and augmentation effects.
#
# Note a mosaic dataloader is used for training (shown below), a new dataloading concept developed by Glenn Jocher and first featured in [YOLOv4](https://arxiv.org/abs/2004.10934).

# %%
# first, display our ground truth data
print("GROUND TRUTH TRAINING DATA:")
Image(filename='/content/yolov5/runs/train/yolov5s_results3/test_batch0_labels.jpg', width=900)

# %%
# print out an augmented training example
print("GROUND TRUTH AUGMENTED TRAINING DATA:")
Image(filename='/content/yolov5/runs/train/yolov5s_results3/train_batch0.jpg', width=900)

# %% [markdown]
# #Run Inference  With Trained Weights
# Run inference with a pretrained checkpoint on contents of `test/images` folder downloaded from Roboflow.

# %%
# trained weights are saved by default in our weights folder
# %ls runs/
# Out:
# train/

# %%
# %ls runs/train/yolov5s_results2/weights
# Out:
# best.pt  last.pt

# %%
# %cd ..
# Out:
# /content

# %%
# !unzip test.zip
# Out:
# Archive:  test.zip
#   inflating: test/cctv5-1-1.jpg
#   inflating: test/cctv5-1-10.jpg
#   inflating: test/cctv5-1-2.jpg
#   inflating: test/cctv5-1-3.jpg
#   inflating: test/cctv5-1-4.jpg
#   inflating: test/cctv5-1-5.jpg
#   inflating: test/cctv5-1-6.jpg
#   inflating: test/cctv5-1-7.jpg
#   inflating: test/cctv5-1-8.jpg
#   inflating: test/cctv5-1-9.jpg

# %%
# when we ran this, we saw .007 second inference time. That is 140 FPS on a TESLA P100!
# use the best weights!
# %cd /content/yolov5/
# !python detect.py --weights runs/train/yolov5s_results3/weights/best.pt --img 640 --conf 0.1 --source ../test
# Out:
# /content/yolov5
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.1, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='../test', update=False, view_img=False, weights=['runs/train/yolov5s_results3/weights/best.pt'])
# YOLOv5 v4.0-126-g886f1c0 torch 1.8.1+cu101 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7053910 parameters, 0 gradients, 16.3 GFLOPS
# image 1/10 /content/yolov5/../test/cctv5-1-1.jpg: 448x640 Done. (0.010s)
# image 2/10 /content/yolov5/../test/cctv5-1-10.jpg: 448x640 Done. (0.009s)
# image 3/10 /content/yolov5/../test/cctv5-1-2.jpg: 448x640 Done. (0.009s)
# image 4/10 /content/yolov5/../test/cctv5-1-3.jpg: 448x640 Done. (0.009s)
# image 5/10 /content/yolov5/../test/cctv5-1-4.jpg: 448x640 Done. (0.009s)
# image 6/10 /content/yolov5/../test/cctv5-1-5.jpg: 448x640 Done. (0.009s)
# image 7/10 /content/yolov5/../test/cctv5-1-6.jpg: 448x640 Done. (0.009s)
# image 8/10 /content/yolov5/../test/cctv5-1-7.jpg: 448x640 Done. (0.009s)
# image 9/10 /content/yolov5/../test/cctv5-1-8.jpg: 448x640 Done. (0.009s)
# image 10/10 /content/yolov5/../test/cctv5-1-9.jpg: 448x640 Done. (0.009s)
# Results saved to runs/detect/exp8
# Done. (1.870s)

# %%
#display inference on ALL test images
#this looks much better with longer training above

import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/runs/detect/exp8/*.jpg'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")

# %% [markdown]
# # Export Trained Weights for Future Inference
#
# Now that you have trained your custom detector, you can export the trained weights you have made here for inference on your device elsewhere

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cp /content/yolov5/runs/train/yolov5s_results/weights/best.pt /content/gdrive/My\ Drive

# %% [markdown]
# ## Congrats!
#
# Hope you enjoyed this!
#
# --Team [Roboflow](https://roboflow.ai)
